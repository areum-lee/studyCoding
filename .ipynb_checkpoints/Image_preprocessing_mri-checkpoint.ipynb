# %%
import os
import glob
import numpy as np
import SimpleITK as sitk
import nibabel as nib
from PIL import Image
from sklearn.cross_validation import StratifiedKFold
import os, glob, tqdm, cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## nii open
#
# - nii 파일 shape
#     - depth, width, height

# %%
cv_path=sorted(glob.glob('C:/Users/AREUM/Desktop/0_git/studyCoding/files/*'))
for adc_name in cv_path:
    print adc_name
    roi = sitk.GetArrayFromImage(sitk.ReadImage(adc_name))
    print roi.shape
# Out:
# C:/Users/AREUM/Desktop/0_git/studyCoding/files\01_ADC.nii
# (20L, 384L, 384L)

# %% [markdown]
# ## 2d 이미지 출력

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.imshow(roi[8],'gray')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(roi[14],'gray')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(roi[19],'gray')
plt.axis('off')
# Out:
# (-0.5, 383.5, 383.5, -0.5)

# %% [markdown]
# ## flip updown, leftright

# %% [markdown]
# ## save nii

# %%
patient_num=int(100)
mask_path = os.path.join('C:/Users/AREUM/Desktop/0_git/studyCoding/files/', '%03d.nii'%patient_num)
a1=sitk.GetImageFromArray(roi)
sitk.WriteImage(a1,mask_path)

# %% [markdown]
# ## save npy
